# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Traversing List

# %%
def traversinglst(lst):
    for idx, val in enumerate(lst):
        print(lst[idx], end = ' ')

# %%
aquatic_animals = ['🐋', '🐟️', '🦑', '🐡', '🦈']

traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🦑 🐡 🦈

# %% [markdown]
# ### Updating List

# %%
aquatic_animals[2] = '🐙'

traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🐙 🐡 🦈

# %% [markdown]
# ### List Method

# %%
aquatic_animals.insert(2, '🦑')
traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🦑 🐙 🐡 🦈

# %%
aquatic_animals.append('🐋')
traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🦑 🐙 🐡 🦈 🐋

# %%
pet_animals = ['🐶', '🐰']

aquatic_animals.extend(pet_animals)
animals = aquatic_animals 
traversinglst(animals)
# Out:
# 🐋 🐟️ 🦑 🐙 🐡 🦈 🐋 🐶 🐰

# %% [markdown]
# ### Slicing & Deletion

# %%
pet_animals = aquatic_animals[7:]
traversinglst(pet_animals)
# Out:
# 🐶 🐰

# %%
pet_animals.pop() # default value of index = -1
traversinglst(pet_animals)
# Out:
# 🐶

# %%
del aquatic_animals[7:]
traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🦑 🐙 🐡 🦈 🐋

# %%
aquatic_animals.remove('🐙')
traversinglst(aquatic_animals)
# Out:
# 🐋 🐟️ 🦑 🐡 🦈 🐋

# %% [markdown]
# ### Searching in List

# %%
print('🐟️' in aquatic_animals, 'The fish exists!!')
# Out:
# True The fish exists!!

# %%
def searchInList(lst, value):
    try:
        for val in lst:
            if val == value:
                return lst.index(val)
    except:
        print('The value didn\'t exists in list')

# %%
searchInList(aquatic_animals, '🐟️')
# Out:
# 1

# %% [markdown]
# ### Operator in lst

# %%
a = [1, 2, 3]
b = [4, 5, 6]

print('Appended List a and b: ', a + b)
print('Repeating the list a: ', a * 2)
print('Length in list a: ', len(a))
print('Maximum in list a: ', max(a))
print('Minimum in list a: ', min(a))
print('Sum of list a: ', sum(a))
print('Average of list a: ', sum(a)/len(a))
# Out:
# Appended List a and b:  [1, 2, 3, 4, 5, 6]
# Repeating the list a:  [1, 2, 3, 1, 2, 3]
# Length in list a:  3
# Maximum in list a:  3
# Minimum in list a:  1
# Sum of list a:  6
# Average of list a:  2.0

# %% [markdown]
# ### ```list()```,  ```split()``` & ```joint()```

# %%
a = 'spam spam spam'

a_lst = list(a.split())
print(a_lst)

print(' '.join(a_lst))
# Out:
# ['spam', 'spam', 'spam']
# spam spam spam

# %% [markdown]
# ### Time & Space Complexity in list
#
# ![image.png](attachment:image.png)
